# %%
Lesson 3 9.02
Мы разбирали условие задачи на codeforces.com
Создали для этого папку в visual studio
У python нет ограничений по памяти и времени, на это в условии не смотрим
Мы копировали в visual studio 3 разных решения 1 задачи 
Потом писали свое решение в виде обычной записи, потом смотрели на код какого из 3 решений оно больше похоже 
Это решение мы отправили 3-телеграмм ботам и получили подробный разбор решения, который сохранили в visual studio
Сделали commit
И сохранили решение задачи на codeforces.com

Посмотрели как участовать в Calculator - ищем в поиске и, выбираем язык, выбираем задачу, копируем ссылку и т.д

Перенесли папку Github с рабочего стола в документы

Переключались между вкладками alt tab
Необходимо пройти 2 курса по питону в течение 2-3 недель
Надо сделать проводник и горячую клавишу для языка
